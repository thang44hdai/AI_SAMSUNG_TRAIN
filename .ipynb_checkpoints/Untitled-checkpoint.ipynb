# %%
import pandas as pd
import numpy as np

#Bài 1:
data = pd.read_csv("P4AI_BT1.csv")
display(data)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           NaN          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          NaN     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          NaN           5.0          1.9  Virginica
# 147           NaN          NaN           5.2          2.0  Virginica
# 148           NaN          3.4           NaN          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
#Bài 2:

#Phương pháp trung bình

df1 = data.copy()

# Tiến hành thay giá trị 'NaN' bằng giá trị trung bình
#fillna: Hàm điền giá trị NaN
#mode: Hàm lấy giá trị có tần số xuất hiện lớn nhất

df1['sepal.length'].fillna(df1['sepal.length'].mode()[0], inplace = True)
df1['sepal.width'].fillna(df1['sepal.width'].mode()[0], inplace = True)
df1['petal.length'].fillna(df1['petal.length'].mode()[0], inplace = True)
df1['petal.width'].fillna(df1['petal.width'].mode()[0], inplace = True)
display(df1.isna().sum())

#Phương pháp tần số cao nhất

df1 = data.copy()

# Tiến hành thay giá trị 'NaN' bằng giá trị trung bình
#fillna: Hàm điền giá trị NaN
#mode: Hàm lấy giá trị có tần số xuất hiện lớn nhất

df1['sepal.length'].fillna(df1['sepal.length'].mode()[0], inplace = True)
df1['sepal.width'].fillna(df1['sepal.width'].mode()[0], inplace = True)
df1['petal.length'].fillna(df1['petal.length'].mode()[0], inplace = True)
df1['petal.width'].fillna(df1['petal.width'].mode()[0], inplace = True)
display(df1.isna().sum())
# Out:
# sepal.length     0
# sepal.width      0
# petal.length     0
# petal.width      0
# variety         15
# dtype: int64
# sepal.length     0
# sepal.width      0
# petal.length     0
# petal.width      0
# variety         15
# dtype: int64

# %%
#Bài 3:
df2 = df1[(df1['sepal.length'] > 5) & (df1['sepal.width'] > 3)];
display(df2)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 5             5.4          3.9           1.7          0.4      Setosa
# 6             5.1          3.4           1.4          0.3      Setosa
# 7             5.1          3.4           1.5          0.2      Setosa
# 10            5.4          3.7           1.5          0.2      Setosa
# 15            5.7          4.4           1.5          0.2      Setosa
# 16            5.4          3.9           1.3          0.4      Setosa
# 17            5.1          3.5           1.4          0.3         NaN
# 18            5.7          3.8           1.7          0.2      Setosa
# 19            5.1          3.8           1.5          0.3      Setosa
# 20            5.4          3.4           1.4          0.2      Setosa
# 21            5.1          3.7           1.4          0.4      Setosa
# 23            5.1          3.3           1.7          0.5      Setosa
# 27            5.2          3.5           1.5          0.2         NaN
# 28            5.2          3.4           1.4          0.2      Setosa
# 31            5.4          3.4           1.5          0.4      Setosa
# 32            5.2          4.1           1.5          0.1      Setosa
# 33            5.5          4.2           1.4          0.2         NaN
# 36            5.5          3.5           1.3          0.2      Setosa
# 39            5.1          3.4           1.5          0.2      Setosa
# 43            5.1          3.5           1.6          0.6      Setosa
# 44            5.1          3.8           1.9          0.2      Setosa
# 46            5.1          3.8           1.6          0.2      Setosa
# 47            5.1          3.2           1.4          0.2      Setosa
# 48            5.3          3.7           1.5          0.2      Setosa
# 50            7.0          3.2           4.7          1.4         NaN
# 51            6.4          3.2           4.5          0.2  Versicolor
# 52            5.1          3.1           4.9          1.5  Versicolor
# 56            6.3          3.3           4.7          1.6  Versicolor
# 65            6.7          3.1           4.4          1.4  Versicolor
# 70            5.9          3.2           4.8          1.8         NaN
# 85            5.1          3.4           4.5          1.6  Versicolor
# 86            6.7          3.1           4.7          1.5  Versicolor
# 100           6.3          3.3           6.0          0.2   Virginica
# 110           6.5          3.2           5.1          2.0   Virginica
# 115           6.4          3.2           5.3          2.3         NaN
# 117           7.7          3.8           6.7          2.2   Virginica
# 120           6.9          3.2           5.7          2.3   Virginica
# 124           6.7          3.3           5.7          2.1   Virginica
# 125           7.2          3.2           6.0          1.8   Virginica
# 131           7.9          3.8           6.4          2.0   Virginica
# 136           6.3          3.4           5.6          2.4   Virginica
# 137           6.4          3.1           5.5          1.8   Virginica
# 139           6.9          3.1           5.4          0.2   Virginica
# 141           6.9          3.1           5.1          2.3   Virginica
# 143           6.8          3.2           5.9          2.3   Virginica
# 148           5.1          3.4           1.4          2.3   Virginica

# %%
#Bài 4:

df2 = df1.copy()

sepal_length_max = df2["sepal.length"].max()
sepal_length_min = df2["sepal.length"].min()
sepal_width_max = df2["sepal.width"].max()
sepal_width_min = df2["sepal.width"].min()
petal_length_max = df2["petal.length"].max()
petal_length_min = df2["petal.length"].min()
petal_width_max = df2["petal.width"].max()
petal_width_min = df2["petal.width"].min()

df2['sepal.length'] = (df2['sepal.length'] - sepal_length_min)/(sepal_length_max - sepal_length_min)
df2['sepal.width'] = (df2['sepal.width'] - sepal_width_min)/(sepal_width_max - sepal_width_min)
df2['petal.length'] = (df2['petal.length'] - petal_length_min)/(petal_length_max - petal_length_min)
df2['petal.width'] = (df2['petal.width'] - petal_width_min)/(petal_width_max - petal_width_min)

display(df2)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0        0.222222     0.625000      0.067797     0.041667     Setosa
# 1        0.166667     0.416667      0.067797     0.041667     Setosa
# 2        0.111111     0.500000      0.050847     0.041667     Setosa
# 3        0.083333     0.458333      0.084746     0.041667     Setosa
# 4        0.194444     0.666667      0.067797     0.041667     Setosa
# ..            ...          ...           ...          ...        ...
# 145      0.666667     0.416667      0.711864     0.916667  Virginica
# 146      0.555556     0.416667      0.677966     0.750000  Virginica
# 147      0.222222     0.416667      0.711864     0.791667  Virginica
# 148      0.222222     0.583333      0.067797     0.916667  Virginica
# 149      0.444444     0.416667      0.694915     0.708333  Virginica
#
# [150 rows x 5 columns]

# %%
#Bài 5:
df3 = df2.copy()
df3['variety'].unique()
dummies = pd.get_dummies(df3['variety'])
df3 = pd.concat([df3,dummies], axis=1)
df3.drop('variety', axis=1, inplace=True)
display(df3)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  Setosa  Versicolor  \
# 0        0.222222     0.625000      0.067797     0.041667    True       False
# 1        0.166667     0.416667      0.067797     0.041667    True       False
# 2        0.111111     0.500000      0.050847     0.041667    True       False
# 3        0.083333     0.458333      0.084746     0.041667    True       False
# 4        0.194444     0.666667      0.067797     0.041667    True       False
# ..            ...          ...           ...          ...     ...         ...
# 145      0.666667     0.416667      0.711864     0.916667   False       False
# 146      0.555556     0.416667      0.677966     0.750000   False       False
# 147      0.222222     0.416667      0.711864     0.791667   False       False
# 148      0.222222     0.583333      0.067797     0.916667   False       False
# 149      0.444444     0.416667      0.694915     0.708333   False       False
#
#      Virginica
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 145       True
# 146       True
# 147       True
# 148       True
# 149       True
#
# [150 rows x 7 columns]

# %%
#Bài 6:

df4 = df3.copy();

df4['sepal.length'] = pd.cut(df4["sepal.length"],
       bins=[-0.1, 0.2, 0.4, 0.6, 0.8, 1],
       labels=["Very Short", "Short", "Medium", "Long", "Very Long"])

display(df4)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width  Setosa  Versicolor  \
# 0          Short     0.625000      0.067797     0.041667    True       False
# 1     Very Short     0.416667      0.067797     0.041667    True       False
# 2     Very Short     0.500000      0.050847     0.041667    True       False
# 3     Very Short     0.458333      0.084746     0.041667    True       False
# 4     Very Short     0.666667      0.067797     0.041667    True       False
# ..           ...          ...           ...          ...     ...         ...
# 145         Long     0.416667      0.711864     0.916667   False       False
# 146       Medium     0.416667      0.677966     0.750000   False       False
# 147        Short     0.416667      0.711864     0.791667   False       False
# 148        Short     0.583333      0.067797     0.916667   False       False
# 149       Medium     0.416667      0.694915     0.708333   False       False
#
#      Virginica
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 145       True
# 146       True
# 147       True
# 148       True
# 149       True
#
# [150 rows x 7 columns]

# %%
#Bài 7:

df5 = df4.sample(frac=0.5, replace=True)
display(df5)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width  Setosa  Versicolor  \
# 55         Short     0.333333      0.067797     0.500000   False        True
# 107    Very Long     0.375000      0.898305     0.041667   False       False
# 124         Long     0.541667      0.796610     0.833333   False       False
# 33         Short     0.916667      0.067797     0.041667   False       False
# 148        Short     0.583333      0.067797     0.916667   False       False
# 132       Medium     0.333333      0.779661     0.875000   False       False
# 131    Very Long     0.750000      0.915254     0.791667   False       False
# 6          Short     0.583333      0.067797     0.083333    True       False
# 126       Medium     0.333333      0.644068     0.708333   False       False
# 2     Very Short     0.500000      0.050847     0.041667    True       False
# 114       Medium     0.333333      0.694915     0.958333   False       False
# 92        Medium     0.250000      0.508475     0.458333   False        True
# 115       Medium     0.500000      0.728814     0.916667   False       False
# 58          Long     0.375000      0.610169     0.500000   False        True
# 35    Very Short     0.500000      0.033898     0.041667    True       False
# 37    Very Short     0.666667      0.067797     0.000000    True       False
# 144         Long     0.416667      0.796610     1.000000   False       False
# 103       Medium     0.416667      0.779661     0.708333   False       False
# 62        Medium     0.083333      0.508475     0.375000   False        True
# 79         Short     0.250000      0.423729     0.375000   False        True
# 80         Short     0.166667      0.474576     0.416667   False        True
# 125    Very Long     0.500000      0.847458     0.708333   False       False
# 78        Medium     0.375000      0.593220     0.583333   False        True
# 33         Short     0.916667      0.067797     0.041667   False       False
# 114       Medium     0.333333      0.694915     0.958333   False       False
# 91        Medium     0.416667      0.610169     0.541667   False       False
# 42    Very Short     0.416667      0.050847     0.041667    True       False
# 31         Short     0.583333      0.084746     0.125000    True       False
# 106   Very Short     0.208333      0.593220     0.666667   False       False
# 135    Very Long     0.416667      0.864407     0.916667   False       False
# 72        Medium     0.208333      0.661017     0.583333   False        True
# 149       Medium     0.416667      0.694915     0.708333   False       False
# 142       Medium     0.291667      0.067797     0.750000   False       False
# 123       Medium     0.291667      0.661017     0.708333   False       False
# 52         Short     0.458333      0.661017     0.583333   False        True
# 129    Very Long     0.416667      0.813559     0.625000   False       False
# 140         Long     0.416667      0.067797     0.958333   False       False
# 131    Very Long     0.750000      0.915254     0.791667   False       False
# 96         Short     0.375000      0.542373     0.500000   False        True
# 28         Short     0.583333      0.067797     0.041667    True       False
# 87        Medium     0.125000      0.576271     0.500000   False        True
# 3     Very Short     0.458333      0.084746     0.041667    True       False
# 66         Short     0.416667      0.067797     0.583333   False        True
# 55         Short     0.333333      0.067797     0.500000   False        True
# 102         Long     0.416667      0.830508     0.833333   False       False
# 139         Long     0.458333      0.745763     0.041667   False       False
# 4     Very Short     0.666667      0.067797     0.041667    True       False
# 137       Medium     0.458333      0.762712     0.708333   False       False
# 131    Very Long     0.750000      0.915254     0.791667   False       False
# 105    Very Long     0.416667      0.067797     0.833333   False       False
# 130    Very Long     0.333333      0.864407     0.041667   False       False
# 147        Short     0.416667      0.711864     0.791667   False       False
# 28         Short     0.583333      0.067797     0.041667    True       False
# 143         Long     0.500000      0.830508     0.916667   False       False
# 131    Very Long     0.750000      0.915254     0.791667   False       False
# 30    Very Short     0.458333      0.101695     0.041667    True       False
# 44         Short     0.750000      0.152542     0.041667    True       False
# 112         Long     0.416667      0.762712     0.833333   False       False
# 129    Very Long     0.416667      0.813559     0.625000   False       False
# 46         Short     0.750000      0.101695     0.041667    True       False
# 53         Short     0.125000      0.508475     0.041667   False        True
# 104        Short     0.416667      0.813559     0.875000   False       False
# 136       Medium     0.583333      0.779661     0.958333   False       False
# 55         Short     0.333333      0.067797     0.500000   False        True
# 27         Short     0.625000      0.084746     0.041667   False       False
# 148        Short     0.583333      0.067797     0.916667   False       False
# 147        Short     0.416667      0.711864     0.791667   False       False
# 101       Medium     0.291667      0.694915     0.750000   False       False
# 61         Short     0.416667      0.542373     0.583333   False        True
# 101       Medium     0.291667      0.694915     0.750000   False       False
# 141         Long     0.458333      0.694915     0.916667   False       False
# 44         Short     0.750000      0.152542     0.041667    True       False
# 121        Short     0.333333      0.661017     0.041667   False       False
# 57    Very Short     0.166667      0.389831     0.375000   False        True
# 98         Short     0.208333      0.338983     0.416667   False        True
#
#      Virginica
# 55       False
# 107       True
# 124       True
# 33       False
# 148       True
# 132       True
# 131       True
# 6        False
# 126       True
# 2        False
# 114       True
# 92       False
# 115      False
# 58       False
# 35       False
# 37       False
# 144      False
# 103       True
# 62       False
# 79       False
# 80       False
# 125       True
# 78       False
# 33       False
# 114       True
# 91       False
# 42       False
# 31       False
# 106       True
# 135       True
# 72       False
# 149       True
# 142       True
# 123       True
# 52       False
# 129       True
# 140       True
# 131       True
# 96       False
# 28       False
# 87       False
# 3        False
# 66       False
# 55       False
# 102       True
# 139       True
# 4        False
# 137       True
# 131       True
# 105       True
# 130       True
# 147       True
# 28       False
# 143       True
# 131       True
# 30       False
# 44       False
# 112       True
# 129       True
# 46       False
# 53       False
# 104       True
# 136       True
# 55       False
# 27       False
# 148       True
# 147       True
# 101       True
# 61       False
# 101       True
# 141       True
# 44       False
# 121       True
# 57       False
# 98       False
